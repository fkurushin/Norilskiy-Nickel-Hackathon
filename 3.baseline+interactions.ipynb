# %%
import re
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv("data/df_hack_final_processed.csv")
df = df.astype({'MEAS_DT': 'datetime64[ns]'})

# %%
interaction_graph = {
    "fm1" : [],
    "fm2" : ["Cu_1.1C", "Ni_1.1C", "Cu_1.2C", "Ni_1.2C"],
    "fm3" : ["Cu_2.1C", "Ni_2.1C", "Cu_2.2C", "Ni_2.2C"],
    "fm4" : ["Cu_2.1C", "Ni_2.1C", "Cu_2.2C", "Ni_2.2C", "Cu_3.1C", "Ni_3.1C", "Cu_3.2C", "Ni_3.2C", "Ni_6.1C", "Ni_6.2C"],
    "fm5" : ["Ni_4.1C", "Ni_4.1T"],
    "fm6" : ["Ni_5.1C", "Ni_5.1T", "Ni_5.2C", "Ni_5.2T"]
    }

# %%
def get_dataframe_per_fm(df, i, j, train=True):
    non_digit_features = [col for col in df.columns.tolist() if not re.findall(r'\d+', col)]
    filtered_columns_1 = [col for col in df.columns.tolist() if re.findall(f'{i}\\.{j}', col)]
    filtered_columns_2 = [col for col in df.columns.tolist() if re.findall(f'_{i}$', col)]
    add_features = []
    if train:
        add_features = interaction_graph[f'fm{i}']

    return df[non_digit_features+filtered_columns_1+filtered_columns_2 + add_features]

dfd = {f"fm{i}.{j}" : get_dataframe_per_fm(df, i, j) for j in range(1,3) for i in range(1,7)}

# %%
test_dataframe = pd.read_csv("data/test.csv")
test_dataframe = test_dataframe.astype({'MEAS_DT': 'datetime64[ns]'})

# %%
dfd_test = {f"fm{i}.{j}" : get_dataframe_per_fm(test_dataframe, i, j, False) for j in range(1, 3) for i in range(1, 7)}

# %%
def train_test_split(train_, test_):
    train = pd.concat([train_, test_]).drop_duplicates(subset='MEAS_DT', keep=False)
    test = pd.merge(test_, train_, how='inner', on='MEAS_DT', suffixes=('_y', '_X'))
    return {
        "train" : train, 
        "test" : test
        }

# %%
dfd_tt = {k : train_test_split(df_train_fm, dfd_test[k]) for k, df_train_fm in dfd.items()}

# %% [markdown]
# ## CatBoost

# %%
from catboost import CatBoostRegressor, Pool
from sklearn.metrics import mean_absolute_error
import numpy as np

# %%
from collections import defaultdict

# %%
models = {}
mae_values = defaultdict()
mape_values = defaultdict()

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
for floatmachine_name in dfd_tt.keys():

    train = dfd_tt[floatmachine_name]['train']
    test = dfd_tt[floatmachine_name]['test']

    output_features = [f.replace("_y", "") for f in test.columns.tolist() if "_y" in f]
    train = train.dropna(subset=output_features)

    for output_feature in output_features:
        print(f"training {floatmachine_name} : {output_feature}...")

        features_to_train_on = train.columns.tolist()
        features_to_train_on.remove('MEAS_DT')
        features_to_train_on = [f for f in features_to_train_on if not "min" in f and "max" not in f]

        train_pool = Pool(train[features_to_train_on], label=train[output_feature])
        test_pool = Pool(test[features_to_train_on], label=test[output_feature + "_X"])

        model = CatBoostRegressor(loss_function='MAE')

        model.fit(train_pool, eval_set=test_pool, use_best_model=True, plot=False, silent=True)

        train_predictions = model.predict(train_pool)
        test_predictions = model.predict(test_pool)

        train_mae = mean_absolute_error(train[output_feature], train_predictions)
        test_mae = mean_absolute_error(test[output_feature + "_X"], test_predictions)

        train_mape = mean_absolute_percentage_error(train[output_feature], train_predictions)
        test_mape = mean_absolute_percentage_error(test[output_feature + "_X"], test_predictions)

        mae_values[output_feature] = test_mae
        mape_values[output_feature] = test_mape

        print(f"Metrics for {floatmachine_name} : {output_feature}")
        print(f"Train MAE: {round(train_mae, 4)}, Train MAPE: {round(train_mape, 4)}%")
        print(f"Test MAE: {round(test_mae, 4)}, Test MAPE: {round(test_mape, 4)}%")
        print("----------------------------------//----------------------------------")

        models[f"{floatmachine_name}:{output_feature}"] = model
# Out:
# training fm1.1 : Ni_1.1C_min...
# Metrics for fm1.1 : Ni_1.1C_min
# Train MAE: 0.0764, Train MAPE: 2.9078%
# Test MAE: 0.0716, Test MAPE: 2.6358%
# ----------------------------------//----------------------------------
# training fm1.1 : Ni_1.1C_max...
# Metrics for fm1.1 : Ni_1.1C_max
# Train MAE: 0.0805, Train MAPE: 2.6062%
# Test MAE: 0.0782, Test MAPE: 2.5392%
# ----------------------------------//----------------------------------
# training fm1.1 : Cu_1.1C_min...
# Metrics for fm1.1 : Cu_1.1C_min
# Train MAE: 0.0417, Train MAPE: 0.9467%
# Test MAE: 0.0416, Test MAPE: 0.9407%
# ----------------------------------//----------------------------------
# training fm1.1 : Cu_1.1C_max...
# Metrics for fm1.1 : Cu_1.1C_max
# Train MAE: 0.0418, Train MAPE: 0.8851%
# Test MAE: 0.0468, Test MAPE: 1.0041%
# ----------------------------------//----------------------------------
# training fm2.1 : Cu_2.1T_min...
# Metrics for fm2.1 : Cu_2.1T_min
# Train MAE: 0.0041, Train MAPE: 1.0908%
# Test MAE: 0.0044, Test MAPE: 1.3156%
# ----------------------------------//----------------------------------
# training fm2.1 : Cu_2.1T_max...
# Metrics for fm2.1 : Cu_2.1T_max
# Train MAE: 0.0058, Train MAPE: 1.1917%
# Test MAE: 0.0055, Test MAPE: 1.3647%
# ----------------------------------//----------------------------------
# training fm3.1 : Cu_3.1T_min...
# Metrics for fm3.1 : Cu_3.1T_min
# Train MAE: 0.1194, Train MAPE: 13.2691%
# Test MAE: 0.1494, Test MAPE: 12.2007%
# ----------------------------------//----------------------------------
# training fm3.1 : Cu_3.1T_max...
# Metrics for fm3.1 : Cu_3.1T_max
# Train MAE: 0.244, Train MAPE: 11.8818%
# Test MAE: 0.279, Test MAPE: 12.6212%
# ----------------------------------//----------------------------------
# training fm4.1 : Ni_4.1T_min...
# Metrics for fm4.1 : Ni_4.1T_min
# Train MAE: 0.0062, Train MAPE: 0.8686%
# Test MAE: 0.0075, Test MAPE: 1.0234%
# ----------------------------------//----------------------------------
# training fm4.1 : Ni_4.1T_max...
# Metrics for fm4.1 : Ni_4.1T_max
# Train MAE: 0.0069, Train MAPE: 0.8914%
# Test MAE: 0.0082, Test MAPE: 1.053%
# ----------------------------------//----------------------------------
# training fm4.1 : Ni_4.1C_min...
# Metrics for fm4.1 : Ni_4.1C_min
# Train MAE: 0.0443, Train MAPE: 0.9857%
# Test MAE: 0.0484, Test MAPE: 1.0481%
# ----------------------------------//----------------------------------
# training fm4.1 : Ni_4.1C_max...
# Metrics for fm4.1 : Ni_4.1C_max
# Train MAE: 0.0486, Train MAPE: 0.9973%
# Test MAE: 0.0526, Test MAPE: 1.074%
# ----------------------------------//----------------------------------
# training fm5.1 : Ni_5.1T_min...
# Metrics for fm5.1 : Ni_5.1T_min
# Train MAE: 0.0083, Train MAPE: 1.1004%
# Test MAE: 0.008, Test MAPE: 1.1516%
# ----------------------------------//----------------------------------
# training fm5.1 : Ni_5.1T_max...
# Metrics for fm5.1 : Ni_5.1T_max
# Train MAE: 0.0113, Train MAPE: 1.2924%
# Test MAE: 0.0082, Test MAPE: 1.1275%
# ----------------------------------//----------------------------------
# training fm5.1 : Ni_5.1C_min...
# Metrics for fm5.1 : Ni_5.1C_min
# Train MAE: 0.0682, Train MAPE: 1.0892%
# Test MAE: 0.0668, Test MAPE: 1.0374%
# ----------------------------------//----------------------------------
# training fm5.1 : Ni_5.1C_max...
# Metrics for fm5.1 : Ni_5.1C_max
# Train MAE: 0.0564, Train MAPE: 0.8417%
# Test MAE: 0.0558, Test MAPE: 0.8239%
# ----------------------------------//----------------------------------
# training fm6.1 : Ni_6.1T_min...
# Metrics for fm6.1 : Ni_6.1T_min
# Train MAE: 0.0147, Train MAPE: 1.049%
# Test MAE: 0.016, Test MAPE: 1.1512%
# ----------------------------------//----------------------------------
# training fm6.1 : Ni_6.1T_max...
# Metrics for fm6.1 : Ni_6.1T_max
# Train MAE: 0.0158, Train MAPE: 1.0597%
# Test MAE: 0.0165, Test MAPE: 1.1209%
# ----------------------------------//----------------------------------
# training fm6.1 : Ni_6.1C_min...
# Metrics for fm6.1 : Ni_6.1C_min
# Train MAE: 0.0917, Train MAPE: 1.0353%
# Test MAE: 0.0953, Test MAPE: 1.0557%
# ----------------------------------//----------------------------------
# training fm6.1 : Ni_6.1C_max...
# Metrics for fm6.1 : Ni_6.1C_max
# Train MAE: 0.0951, Train MAPE: 1.0001%
# Test MAE: 0.1028, Test MAPE: 1.0806%
# ----------------------------------//----------------------------------
# training fm1.2 : Ni_1.2C_min...
# Metrics for fm1.2 : Ni_1.2C_min
# Train MAE: 0.0654, Train MAPE: 2.4085%
# Test MAE: 0.0656, Test MAPE: 2.3311%
# ----------------------------------//----------------------------------
# training fm1.2 : Ni_1.2C_max...
# Metrics for fm1.2 : Ni_1.2C_max
# Train MAE: 0.067, Train MAPE: 2.0965%
# Test MAE: 0.0655, Test MAPE: 2.087%
# ----------------------------------//----------------------------------
# training fm1.2 : Cu_1.2C_min...
# Metrics for fm1.2 : Cu_1.2C_min
# Train MAE: 0.0782, Train MAPE: 1.7015%
# Test MAE: 0.0692, Test MAPE: 1.4437%
# ----------------------------------//----------------------------------
# training fm1.2 : Cu_1.2C_max...
# Metrics for fm1.2 : Cu_1.2C_max
# Train MAE: 0.0968, Train MAPE: 1.8045%
# Test MAE: 0.0704, Test MAPE: 1.372%
# ----------------------------------//----------------------------------
# training fm2.2 : Cu_2.2T_min...
# Metrics for fm2.2 : Cu_2.2T_min
# Train MAE: 0.0049, Train MAPE: 1.1379%
# Test MAE: 0.0052, Test MAPE: 1.2408%
# ----------------------------------//----------------------------------
# training fm2.2 : Cu_2.2T_max...
# Metrics for fm2.2 : Cu_2.2T_max
# Train MAE: 0.0067, Train MAPE: 1.2719%
# Test MAE: 0.006, Test MAPE: 1.3025%
# ----------------------------------//----------------------------------
# training fm3.2 : Cu_3.2T_min...
# Metrics for fm3.2 : Cu_3.2T_min
# Train MAE: 0.0784, Train MAPE: 7.1503%
# Test MAE: 0.0854, Test MAPE: 6.9312%
# ----------------------------------//----------------------------------
# training fm3.2 : Cu_3.2T_max...
# Metrics for fm3.2 : Cu_3.2T_max
# Train MAE: 0.1511, Train MAPE: 8.2722%
# Test MAE: 0.1122, Test MAPE: 6.92%
# ----------------------------------//----------------------------------
# training fm4.2 : Ni_4.2T_min...
# Metrics for fm4.2 : Ni_4.2T_min
# Train MAE: 0.0123, Train MAPE: 1.5378%
# Test MAE: 0.0116, Test MAPE: 1.5562%
# ----------------------------------//----------------------------------
# training fm4.2 : Ni_4.2T_max...
# Metrics for fm4.2 : Ni_4.2T_max
# Train MAE: 0.012, Train MAPE: 1.365%
# Test MAE: 0.016, Test MAPE: 1.6894%
# ----------------------------------//----------------------------------
# training fm4.2 : Ni_4.2C_min...
# Metrics for fm4.2 : Ni_4.2C_min
# Train MAE: 0.0702, Train MAPE: 1.8544%
# Test MAE: 0.0729, Test MAPE: 1.8229%
# ----------------------------------//----------------------------------
# training fm4.2 : Ni_4.2C_max...
# Metrics for fm4.2 : Ni_4.2C_max
# Train MAE: 0.0613, Train MAPE: 1.4346%
# Test MAE: 0.0683, Test MAPE: 1.5443%
# ----------------------------------//----------------------------------
# training fm5.2 : Ni_5.2T_min...
# Metrics for fm5.2 : Ni_5.2T_min
# Train MAE: 0.0085, Train MAPE: 1.1846%
# Test MAE: 0.0081, Test MAPE: 1.1818%
# ----------------------------------//----------------------------------
# training fm5.2 : Ni_5.2T_max...
# Metrics for fm5.2 : Ni_5.2T_max
# Train MAE: 0.0115, Train MAPE: 1.3154%
# Test MAE: 0.0084, Test MAPE: 1.1618%
# ----------------------------------//----------------------------------
# training fm5.2 : Ni_5.2C_min...
# Metrics for fm5.2 : Ni_5.2C_min
# Train MAE: 0.0943, Train MAPE: 1.47%
# Test MAE: 0.1082, Test MAPE: 1.6115%
# ----------------------------------//----------------------------------
# training fm5.2 : Ni_5.2C_max...
# Metrics for fm5.2 : Ni_5.2C_max
# Train MAE: 0.0961, Train MAPE: 1.3819%
# Test MAE: 0.1061, Test MAPE: 1.4772%
# ----------------------------------//----------------------------------
# training fm6.2 : Ni_6.2T_min...
# Metrics for fm6.2 : Ni_6.2T_min
# Train MAE: 0.0327, Train MAPE: 2.5343%
# Test MAE: 0.0347, Test MAPE: 2.7564%
# ----------------------------------//----------------------------------
# training fm6.2 : Ni_6.2T_max...
# Metrics for fm6.2 : Ni_6.2T_max
# Train MAE: 0.0353, Train MAPE: 2.4287%
# Test MAE: 0.0364, Test MAPE: 2.6082%
# ----------------------------------//----------------------------------
# training fm6.2 : Ni_6.2C_min...
# Metrics for fm6.2 : Ni_6.2C_min
# Train MAE: 0.0606, Train MAPE: 0.6784%
# Test MAE: 0.0661, Test MAPE: 0.7181%
# ----------------------------------//----------------------------------
# training fm6.2 : Ni_6.2C_max...
# Metrics for fm6.2 : Ni_6.2C_max
# Train MAE: 0.0602, Train MAPE: 0.6438%
# Test MAE: 0.0642, Test MAPE: 0.6776%
# ----------------------------------//----------------------------------

# %%
mae_list = [v for _,v in mae_values.items()]
mape_list = [v for _,v in mape_values.items()]

print(f"Mean MAE {round(sum(mae_list) / len(mae_list), 4)}")
print(f"Mean MAPE {round(sum(mape_list) / len(mape_list), 4)}%")
# Out:
# Mean MAE 0.0561
# Mean MAPE 2.2451%

# %% [markdown]
# ### create submission

# %%
for floatmachine_name in dfd_tt.keys():

    train = dfd_tt[floatmachine_name]['train']
    test = dfd_tt[floatmachine_name]['test']

    output_features = [f.replace("_y", "") for f in test.columns.tolist() if "_y" in f]
    train = train.dropna(subset=output_features)

    for output_feature in output_features:
        # print(f"training {floatmachine_name} : {output_feature}...")

        features_to_train_on = train.columns.tolist()
        features_to_train_on.remove('MEAS_DT')
        features_to_train_on = [f for f in features_to_train_on if not "min" in f and "max" not in f]

        test_pool = Pool(test[features_to_train_on], label=test[output_feature + "_X"])

        test_predictions = models[f"{floatmachine_name}:{output_feature}"].predict(test_pool)

        test_dataframe[output_feature] = test_predictions

# %% [markdown]
# ### apply contraints

# %%
test_dataframe.head()
# Out:
#               MEAS_DT  Ni_1.1C_min  Ni_1.1C_max  Cu_1.1C_min  Cu_1.1C_max  \
# 0 2024-01-19 12:15:00     2.481546     2.715016     4.713474     4.894614
# 1 2024-01-19 12:30:00     2.482487     2.701063     4.729127     4.898569
# 2 2024-01-19 12:45:00     2.471117     2.674688     4.731913     4.900725
# 3 2024-01-19 13:00:00     2.538296     2.757147     4.800525     4.930732
# 4 2024-01-19 13:15:00     2.410030     2.634403     4.854644     5.020060
#
#    Ni_1.2C_min  Ni_1.2C_max  Cu_1.2C_min  Cu_1.2C_max  Cu_2.1T_min  ...  \
# 0     2.470214     2.775176     4.217431     4.572527     0.432215  ...
# 1     2.487303     2.757664     4.222346     4.518989     0.434375  ...
# 2     2.487283     2.764340     4.216692     4.540899     0.432317  ...
# 3     2.471932     2.768727     4.197948     4.583269     0.432662  ...
# 4     2.504131     2.776939     4.321796     4.620784     0.440222  ...
#
#    Ni_5.2C_min  Ni_5.2C_max  Ni_6.1T_min  Ni_6.1T_max  Ni_6.1C_min  \
# 0     6.285106     6.616127     1.159235     1.198409     8.750826
# 1     6.134394     6.478068     1.168488     1.207221     8.819671
# 2     6.191514     6.529948     1.168365     1.207964     8.836875
# 3     6.234217     6.541920     1.185300     1.226144     8.757807
# 4     6.303597     6.633395     1.172602     1.215029     8.771203
#
#    Ni_6.1C_max  Ni_6.2T_min  Ni_6.2T_max  Ni_6.2C_min  Ni_6.2C_max
# 0     9.022657     1.044972     1.116736     9.016537     9.186243
# 1     9.079372     0.986264     1.066936     8.990309     9.150371
# 2     9.095844     1.023982     1.099386     8.984703     9.148937
# 3     9.031335     1.027313     1.102029     8.979641     9.147365
# 4     9.060555     1.008023     1.095601     9.001304     9.177726
#
# [5 rows x 41 columns]

# %% [markdown]
# #### sliding window

# %%
window_size = 8

def process_column(column):
    return [m for i in range(0, len(column), window_size) for m in [column.iloc[i:i+window_size].mean()] * window_size][:len(column)]

# %%
for col in test_dataframe.columns[1:]:
    test_dataframe[col] = process_column(test_dataframe[col])

# %%
test_dataframe.head()
# Out:
#               MEAS_DT  Ni_1.1C_min  Ni_1.1C_max  Cu_1.1C_min  Cu_1.1C_max  \
# 0 2024-01-19 12:15:00     2.504468     2.718727     4.796418      4.95892
# 1 2024-01-19 12:30:00     2.504468     2.718727     4.796418      4.95892
# 2 2024-01-19 12:45:00     2.504468     2.718727     4.796418      4.95892
# 3 2024-01-19 13:00:00     2.504468     2.718727     4.796418      4.95892
# 4 2024-01-19 13:15:00     2.504468     2.718727     4.796418      4.95892
#
#    Ni_1.2C_min  Ni_1.2C_max  Cu_1.2C_min  Cu_1.2C_max  Cu_2.1T_min  ...  \
# 0      2.56272     2.848913     4.386671     4.726288     0.437108  ...
# 1      2.56272     2.848913     4.386671     4.726288     0.437108  ...
# 2      2.56272     2.848913     4.386671     4.726288     0.437108  ...
# 3      2.56272     2.848913     4.386671     4.726288     0.437108  ...
# 4      2.56272     2.848913     4.386671     4.726288     0.437108  ...
#
#    Ni_5.2C_min  Ni_5.2C_max  Ni_6.1T_min  Ni_6.1T_max  Ni_6.1C_min  \
# 0     6.265971     6.597801     1.169664     1.209819     8.782473
# 1     6.265971     6.597801     1.169664     1.209819     8.782473
# 2     6.265971     6.597801     1.169664     1.209819     8.782473
# 3     6.265971     6.597801     1.169664     1.209819     8.782473
# 4     6.265971     6.597801     1.169664     1.209819     8.782473
#
#    Ni_6.1C_max  Ni_6.2T_min  Ni_6.2T_max  Ni_6.2C_min  Ni_6.2C_max
# 0     9.058255     1.003522     1.084081     9.004448     9.173535
# 1     9.058255     1.003522     1.084081     9.004448     9.173535
# 2     9.058255     1.003522     1.084081     9.004448     9.173535
# 3     9.058255     1.003522     1.084081     9.004448     9.173535
# 4     9.058255     1.003522     1.084081     9.004448     9.173535
#
# [5 rows x 41 columns]

# %% [markdown]
# #### Roundings

# %%
import re
import math

increments = {
    'Ni_1.*C': 0.1,
    'Cu_1.*C': 0.1,
    'Cu_2.*T': 0.01,
    'Cu_3.*T': 0.05,
    'Ni_4.*T': 0.01,
    'Ni_4.*C': 0.05,
    'Ni_5.*T': 0.01,
    'Ni_5.*C': 0.05,
    'Ni_6.*T': 0.01,
    'Ni_6.*C': 0.05
}

def round_up(value, increment):
    if value:
        return math.ceil(value / increment) * increment
    else:
        return value

def round_down(value, increment):
    if value:
        return math.floor(value / increment) * increment
    else:
        return value


for column in test_dataframe.columns:
    if len(column) > 6:
        increment = column[:5] + "*" + column[6]
        if increment in increments:
            increment = increments[column[:5] + "*" + column[6]]
            if column.endswith("min"):
                test_dataframe[column] = test_dataframe[column].apply(round_down, args=(increment,))
            elif column.endswith("max"):
                test_dataframe[column] = test_dataframe[column].apply(round_up, args=(increment,))
            else:
                continue
        else:
            continue

# %%
test_dataframe.head()
# Out:
#               MEAS_DT  Ni_1.1C_min  Ni_1.1C_max  Cu_1.1C_min  Cu_1.1C_max  \
# 0 2024-01-19 12:15:00          2.5          2.8          4.7          5.0
# 1 2024-01-19 12:30:00          2.5          2.8          4.7          5.0
# 2 2024-01-19 12:45:00          2.5          2.8          4.7          5.0
# 3 2024-01-19 13:00:00          2.5          2.8          4.7          5.0
# 4 2024-01-19 13:15:00          2.5          2.8          4.7          5.0
#
#    Ni_1.2C_min  Ni_1.2C_max  Cu_1.2C_min  Cu_1.2C_max  Cu_2.1T_min  ...  \
# 0          2.5          2.9          4.3          4.8         0.43  ...
# 1          2.5          2.9          4.3          4.8         0.43  ...
# 2          2.5          2.9          4.3          4.8         0.43  ...
# 3          2.5          2.9          4.3          4.8         0.43  ...
# 4          2.5          2.9          4.3          4.8         0.43  ...
#
#    Ni_5.2C_min  Ni_5.2C_max  Ni_6.1T_min  Ni_6.1T_max  Ni_6.1C_min  \
# 0         6.25          6.6         1.16         1.21         8.75
# 1         6.25          6.6         1.16         1.21         8.75
# 2         6.25          6.6         1.16         1.21         8.75
# 3         6.25          6.6         1.16         1.21         8.75
# 4         6.25          6.6         1.16         1.21         8.75
#
#    Ni_6.1C_max  Ni_6.2T_min  Ni_6.2T_max  Ni_6.2C_min  Ni_6.2C_max
# 0          9.1          1.0         1.09          9.0          9.2
# 1          9.1          1.0         1.09          9.0          9.2
# 2          9.1          1.0         1.09          9.0          9.2
# 3          9.1          1.0         1.09          9.0          9.2
# 4          9.1          1.0         1.09          9.0          9.2
#
# [5 rows x 41 columns]

# %%
test_dataframe.isna().sum().sum()
# Out:
# 0

# %%
test_dataframe.to_csv('te')
